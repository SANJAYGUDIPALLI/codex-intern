# %% [markdown]
# <a href="https://colab.research.google.com/github/SANJAYGUDIPALLI/codex-intern/blob/main/codexintern.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("/employees.csv")
df.head()
# Out:
#      Name Department  Salary  Expenses
# 0   Alice         HR   50000     20000
# 1     Bob         IT   65000     30000
# 2  George    Finance   70000     50000
# 3   Ethan         IT   62000     40000
# 4   julia  Marketing   58000     20000

# %%
print(df.describe())
# Out:
#              Salary     Expenses
# count      5.000000      5.00000
# mean   61000.000000  32000.00000
# std     7549.834435  13038.40481
# min    50000.000000  20000.00000
# 25%    58000.000000  20000.00000
# 50%    62000.000000  30000.00000
# 75%    65000.000000  40000.00000
# max    70000.000000  50000.00000

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        5 non-null      object
#  1   Department  5 non-null      object
#  2   Salary      5 non-null      int64
#  3   Expenses    5 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 292.0+ bytes
# None

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df["Salary"], kde=True)
plt.title("Distribution of Salary")
plt.show()

# %%
numeric_df = df.select_dtypes(include='number')
print(numeric_df.corr())
# Out:
#             Salary  Expenses
# Salary    1.000000  0.838093
# Expenses  0.838093  1.000000

# %%
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title("data Correlation")
plt.show()

# %%
sns.scatterplot(data=df, x='Expenses', y='Salary')
plt.title("expenses vs salary")
plt.show()

# %%
sns.boxplot(x=df['Salary'])
plt.title("Salary Boxplot")
plt.show()

# %%
import plotly.express as px

fig = px.bar(df, x='Name', y=['Expenses','Salary'],
             title='expenses and salary analysis')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
