# %% [markdown]
# <a href="https://colab.research.google.com/github/SANJAYGUDIPALLI/codex-intern/blob/main/ml_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # my first ml project

# %% [markdown]
# # load data

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("https://raw.githubusercontent.com/SouravG/Housing-price-prediction-using-Regularised-linear-regression/refs/heads/master/Housing%20Price%20data%20set.csv")
df
# Out:
#      Unnamed: 0     price  lotsize  bedrooms  bathrms  stories driveway  \
# 0             1   42000.0     5850         3        1        2      yes
# 1             2   38500.0     4000         2        1        1      yes
# 2             3   49500.0     3060         3        1        1      yes
# 3             4   60500.0     6650         3        1        2      yes
# 4             5   61000.0     6360         2        1        1      yes
# ..          ...       ...      ...       ...      ...      ...      ...
# 541         542   91500.0     4800         3        2        4      yes
# 542         543   94000.0     6000         3        2        4      yes
# 543         544  103000.0     6000         3        2        4      yes
# 544         545  105000.0     6000         3        2        2      yes
# 545         546  105000.0     6000         3        1        2      yes
#
#     recroom fullbase gashw airco  garagepl prefarea
# 0        no      yes    no    no         1       no
# 1        no       no    no    no         0       no
# 2        no       no    no    no         0       no
# 3       yes       no    no    no         0       no
# 4        no       no    no    no         0       no
# ..      ...      ...   ...   ...       ...      ...
# 541     yes       no    no   yes         0       no
# 542      no       no    no   yes         0       no
# 543     yes       no    no   yes         1       no
# 544     yes       no    no   yes         1       no
# 545      no       no    no   yes         1       no
#
# [546 rows x 13 columns]

# %% [markdown]
# # data preparation

# %%
y = df["price"]
y
# Out:
# 0       42000.0
# 1       38500.0
# 2       49500.0
# 3       60500.0
# 4       61000.0
#          ...
# 541     91500.0
# 542     94000.0
# 543    103000.0
# 544    105000.0
# 545    105000.0
# Name: price, Length: 546, dtype: float64

# %%
x = df.drop("price", axis=1)
x
# Out:
#      Unnamed: 0  lotsize  bedrooms  bathrms  stories driveway recroom  \
# 0             1     5850         3        1        2      yes      no
# 1             2     4000         2        1        1      yes      no
# 2             3     3060         3        1        1      yes      no
# 3             4     6650         3        1        2      yes     yes
# 4             5     6360         2        1        1      yes      no
# ..          ...      ...       ...      ...      ...      ...     ...
# 541         542     4800         3        2        4      yes     yes
# 542         543     6000         3        2        4      yes      no
# 543         544     6000         3        2        4      yes     yes
# 544         545     6000         3        2        2      yes     yes
# 545         546     6000         3        1        2      yes      no
#
#     fullbase gashw airco  garagepl prefarea
# 0        yes    no    no         1       no
# 1         no    no    no         0       no
# 2         no    no    no         0       no
# 3         no    no    no         0       no
# 4         no    no    no         0       no
# ..       ...   ...   ...       ...      ...
# 541       no    no   yes         0       no
# 542       no    no   yes         0       no
# 543       no    no   yes         1       no
# 544       no    no   yes         1       no
# 545       no    no   yes         1       no
#
# [546 rows x 12 columns]

# %% [markdown]
# # data splitting

# %%
from sklearn.model_selection import train_test_split

x_train, x_test,y_train,y_test =  train_test_split(x, y, test_size= 0.2 , random_state=100)

# %%
x_train
# Out:
#      Unnamed: 0  lotsize  bedrooms  bathrms  stories driveway recroom  \
# 462         463     2610         3        1        2      yes      no
# 252         253     6930         4        1        2       no      no
# 217         218     3150         3        1        2       no      no
# 22           23     4000         3        1        2      yes      no
# 41           42     4520         3        1        2      yes      no
# ..          ...      ...       ...      ...      ...      ...     ...
# 526         527     5150         3        2        4      yes      no
# 53           54     4040         3        1        2      yes      no
# 350         351     9860         3        1        1      yes      no
# 79           80     6360         2        1        1      yes      no
# 520         521     7680         4        2        4      yes     yes
#
#     fullbase gashw airco  garagepl prefarea
# 462      yes    no    no         0      yes
# 252       no    no    no         1       no
# 217       no    no    no         0       no
# 22        no    no   yes         0       no
# 41       yes    no   yes         0       no
# ..       ...   ...   ...       ...      ...
# 526       no    no   yes         2       no
# 53       yes   yes    no         1       no
# 350       no    no    no         0       no
# 79       yes    no   yes         1       no
# 520       no    no   yes         1       no
#
# [436 rows x 12 columns]

# %%
x_test
# Out:
#      Unnamed: 0  lotsize  bedrooms  bathrms  stories driveway recroom  \
# 54           55     3630         3        3        2       no     yes
# 506         507     9800         4        2        2      yes     yes
# 496         497     4500         3        1        1      yes      no
# 267         268     3600         2        1        1      yes      no
# 153         154     3600         3        1        2       no      no
# ..          ...      ...       ...      ...      ...      ...     ...
# 62           63     4280         2        1        1      yes      no
# 188         189     7424         3        1        1       no      no
# 69           70     4095         3        1        2       no     yes
# 448         449     4320         3        1        2      yes      no
# 268         269     3600         2        1        1      yes      no
#
#     fullbase gashw airco  garagepl prefarea
# 54        no    no    no         0       no
# 506       no    no    no         2       no
# 496      yes    no    no         0       no
# 267       no    no    no         0       no
# 153       no    no    no         1       no
# ..       ...   ...   ...       ...      ...
# 62        no    no   yes         2       no
# 188       no    no    no         0       no
# 69       yes    no   yes         0       no
# 448       no    no    no         2      yes
# 268       no    no    no         0       no
#
# [110 rows x 12 columns]

# %% [markdown]
# # model building

# %% [markdown]
# # linear regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
import pandas as pd

y = df["price"]
x = df.drop("price", axis=1)

categorical_features = x.select_dtypes(include=['object']).columns

encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')

encoded_data = encoder.fit_transform(x[categorical_features])

encoded_df = pd.DataFrame(encoded_data, columns=encoder.get_feature_names_out(categorical_features))

x = x.drop(categorical_features, axis=1)
x = pd.concat([x, encoded_df], axis=1)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=100)

lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder

y = df["price"]
x = df.drop("price", axis=1)

categorical_features = x.select_dtypes(include=['object']).columns

encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')

encoded_data = encoder.fit_transform(x[categorical_features])

encoded_df = pd.DataFrame(encoded_data, columns=encoder.get_feature_names_out(categorical_features))

x = x.drop(categorical_features, axis=1)
x = pd.concat([x, encoded_df], axis=1)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=100)
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # applying the model to make a prediction

# %%
y_lr_train_pred = lr.predict(x_train)
y_lr_test_pred = lr.predict(x_test)

# %%
print(y_lr_train_pred , y_lr_test_pred)
# Out:
# [ 62057.00539625  59616.63827512  40252.05028896  61808.96991299
#   69345.9743751   76082.81132606  53465.13051928  81576.69499037
#   81495.67813151  40523.99196485  47715.12927873  59661.71107075
#   53013.81084488  62717.0316349  107170.78693394  66667.7975306
#   86419.15685458 118079.75580294 100401.91713292  72960.0917875
#   40376.50938992  53990.23931222  79640.64684595  52727.73658284
#   92239.1806742   50249.78094703  65503.24523421  77028.51231414
#   56180.35601757  58468.63725372 101867.70422143  36537.37070929
#  117437.3466085   72325.75746049  64358.1107906   54228.95215526
#   87305.34288834  41018.93596244  51276.1913888  128155.04813644
#  109332.55567184  39460.93886963  97751.52312381  45758.80316907
#  107987.20671007  82253.44414684  43112.48640509  76767.3413411
#   87016.01922237  91064.24319392  63479.13551929  60208.69997248
#  121404.81471624  65255.66710674  30698.8671659   72524.3665079
#   52083.91639847  63418.27171262  42711.86094469  64434.62728387
#   76832.47350108 122956.56560404  93402.86488619  83438.95080235
#   80862.73452564  56224.59555236  72171.04865593  83133.63152366
#  118013.90942561  94286.59229068  55490.98011219  87253.11494419
#   71242.52199542  74381.07553337  46998.39652304  62831.98530663
#   30938.13429903  92947.96063183  79760.45013532  55481.58415204
#   67536.3524384   52373.68906518  85000.84832583  62914.0930949
#   59305.34291497  87629.7800774  101105.5932428   78471.85389232
#   78776.83103078  70865.67888569  50674.17994228  95486.56011636
#   44148.48237076  50807.31600189  74331.89547693  52420.53958884
#   55055.66360737  75521.08290279  56969.85957113  44467.12528361
#  116424.78448695  38663.69776772  66816.80514447  61177.96346699
#  103366.75979813  53853.18431307  82391.33312577  89175.55056625
#   60153.91817221  87635.44277499  74538.80755403  51272.59652449
#   70218.67176253  63806.62590902  47483.02430502  65857.80067015
#   71381.55455125  40023.63666302]

# %%
y_lr_test_pred
# Out:
# array([ 74869.49160017, 100412.03789467,  51665.854519  ,  40020.6929337 ,
#         46348.54376057, 112601.21289412,  81124.43236432,  71900.32749387,
#         55187.51343944,  48972.79583203,  68041.63586303,  42294.70931231,
#         83359.39159372,  69106.63747431,  77063.96914442,  43806.91878218,
#         61186.79465495,  62414.41361298,  72970.35549894,  69489.33583105,
#         58262.10445839,  86374.23911886,  45559.0996423 ,  35585.31783086,
#         66042.22677019,  83442.34397992,  87178.80981093,  92490.90004567,
#         46413.40714165,  37566.61151723,  33050.90024141,  43642.68922578,
#         71238.15041667,  50471.39995794,  53390.47727358,  57001.63013187,
#         54323.66901918,  54714.1387095 ,  75966.88304688,  57922.25211709,
#         86200.61197251,  62734.3408951 ,  55681.87367741,  34008.40056394,
#         43868.14666123,  56438.4147383 ,  49533.44156926,  76128.47327231,
#         63437.48980563,  71200.45456321,  65182.76983297,  75619.40655658,
#         76832.47350108, 122956.56560404,  93402.86488619,  83438.95080235,
#         80862.73452564,  56224.59555236,  72171.04865593,  83133.63152366,
#        118013.90942561,  94286.59229068,  55490.98011219,  87253.11494419,
#         71242.52199542,  74381.07553337,  46998.39652304,  62831.98530663,
#         30938.13429903,  92947.96063183,  79760.45013532,  55481.58415204,
#         67536.3524384 ,  52373.68906518,  85000.84832583,  62914.0930949 ,
#         59305.34291497,  87629.7800774 , 101105.5932428 ,  78471.85389232,
#         78776.83103078,  70865.67888569,  50674.17994228,  95486.56011636,
#         44148.48237076,  50807.31600189,  74331.89547693,  52420.53958884,
#         55055.66360737,  75521.08290279,  56969.85957113,  44467.12528361,
#        116424.78448695,  38663.69776772,  66816.80514447,  61177.96346699,
#        103366.75979813,  53853.18431307,  82391.33312577,  89175.55056625,
#         60153.91817221,  87635.44277499,  74538.80755403,  51272.59652449,
#         70218.67176253,  63806.62590902,  47483.02430502,  65857.80067015,
#         71381.55455125,  40023.63666302])

# %% [markdown]
# # evaluate model perfomnce

# %%
from sklearn.metrics import mean_squared_error, r2_score

lr_train_mse = mean_squared_error(y_train, y_lr_train_pred)
lr_train_r2 = r2_score(y_train, y_lr_train_pred)

lr_test_mse = mean_squared_error(y_test, y_lr_test_pred)
lr_test_r2 = r2_score(y_test, y_lr_test_pred)

# %%
print('LR MSE (TRAIN):', lr_train_mse)
print('LR R2 (TRAIN):', lr_train_r2)
print('LR MSE (TEST):', lr_test_mse)
print('LR R2 (TEST):', lr_test_r2)
# Out:
# LR MSE (TRAIN): 233680129.70583028
# LR R2 (TRAIN): 0.6885124453783493
# LR MSE (TEST): 234179954.40408036
# LR R2 (TEST): 0.5730348032756578

# %%
lr_results = pd.DataFrame(['Linear regression', lr_train_mse, lr_train_r2, lr_test_mse, lr_test_r2]).transpose()
lr_results.columns = ['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2']

# %%
lr_results
# Out:
#               Method     Training MSE Training R2         Test MSE   Test R2
# 0  Linear regression  233680129.70583    0.688512  234179954.40408  0.573035

# %% [markdown]
# # random forest

# %% [markdown]
# # training the model

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(max_depth=2, random_state=100)
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_depth=2, random_state=100)

# %% [markdown]
# # applying the model to make a prediction

# %%
y_rf_train_pred = rf.predict(x_train)
y_rf_test_pred = rf.predict(x_test)

# %% [markdown]
# # evaluate model perfomance

# %%
rf_train_mse = mean_squared_error(y_train, y_rf_train_pred)
rf_train_r2 = r2_score(y_train, y_rf_train_pred)

rf_test_mse = mean_squared_error(y_test, y_rf_test_pred)
rf_test_r2 = r2_score(y_test, y_rf_test_pred)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score


rf = RandomForestRegressor(max_depth=2, random_state=100)
rf.fit(x_train, y_train)

y_rf_train_pred = rf.predict(x_train)
y_rf_test_pred = rf.predict(x_test)


rf_train_mse = mean_squared_error(y_train, y_rf_train_pred)
rf_train_r2 = r2_score(y_train, y_rf_train_pred)

rf_test_mse = mean_squared_error(y_test, y_rf_test_pred)
rf_test_r2 = r2_score(y_test, y_rf_test_pred)

print('RF MSE (TRAIN):', rf_train_mse)
print('RF R2 (TRAIN):', rf_train_r2)
print('RF MSE (TEST):', rf_test_mse)
print('RF R2 (TEST):', rf_test_r2)
# Out:
# RF MSE (TRAIN): 346642987.4695994
# RF R2 (TRAIN): 0.5379368514149063
# RF MSE (TEST): 306715858.8008925
# RF R2 (TEST): 0.4407847703077492

# %%
rf_results = pd.DataFrame(['Random forest', rf_train_mse, rf_train_r2, rf_test_mse, rf_test_r2]).transpose()
rf_results.columns = ['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2']
rf_results
# Out:
#           Method      Training MSE Training R2          Test MSE   Test R2
# 0  Random forest  346642987.469599    0.537937  306715858.800892  0.440785

# %% [markdown]
# # model comoparision

# %%
df_models = pd.concat([lr_results, rf_results], axis=0)
df_models
# Out:
#               Method      Training MSE Training R2          Test MSE   Test R2
# 0  Linear regression   233680129.70583    0.688512   234179954.40408  0.573035
# 0      Random forest  346642987.469599    0.537937  306715858.800892  0.440785

# %%
df_models.reset_index(drop=True)
# Out:
#               Method      Training MSE Training R2          Test MSE   Test R2
# 0  Linear regression   233680129.70583    0.688512   234179954.40408  0.573035
# 1      Random forest  346642987.469599    0.537937  306715858.800892  0.440785

# %% [markdown]
# # data visualization of prediction results

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(5,5))
plt.scatter(x=y_train , y=y_lr_train_pred, alpha=0.3)

z = np.polyfit(y_train, y_lr_train_pred, 1)
p = np.poly1d(z)

plt.plot(y_train,p(y_train),"#F8766D")
plt.ylabel('Predicted price')
plt.xlabel('original price')
# Out:
# Text(0.5, 0, 'original price')
